# %%
import numpy as hui
import matplotlib.pyplot as burger

# %%
y = hui.array( [4,5,4,3,3,4,6])
x = ( hui.arange( 0, y.size, 1) +1)

burger.plot(x,y)

# %%
class hui():

    def __init__(self, x,y,z):
        self.a = x
        self.b = y
        self.c = z

    def add(self,a,b,c):
        sum = a+b+c
        return sum
    
    a = 0
    b = 0
    c = 0
    
obj = hui(100,500,200)
obj.add( obj.a, obj.b, obj.c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 17
#      14     c = 0
#      16 obj = hui(100,500,200)
# ---> 17 obj.add( obj.a + obj.b + obj.c)
#
# TypeError: hui.add() missing 2 required positional arguments: 'b' and 'c'
